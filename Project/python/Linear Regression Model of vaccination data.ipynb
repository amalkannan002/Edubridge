# %% [markdown]
# # import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # read file

# %%
data=pd.read_csv('Datafiles/vaccination_data_latest.csv')

# %% [markdown]
# # view data

# %%
data
# Out:
#                                        State  Total Cases  Active  Discharged  \
# 0                        Andaman And Nicobar         7541       4        7408
# 1                             Andhra Pradesh      1978350   20593     1944267
# 2                          Arunachal Pradesh        49668    3032       46399
# 3                                      Assam       572546   11719      555470
# 4                                      Bihar       725122     357      715119
# 5                                 Chandigarh        61970      27       61132
# 6                               Chhattisgarh      1002958    1780      987642
# 7   Dadra And Nagar Haveli And Daman And Diu        10652      12       10636
# 8                                      Delhi      1436623     516     1411042
# 9                                        Goa       171705     992      167556
# 10                                   Gujarat       825001     204      814720
# ...

# %% [markdown]
# # to check columns and rows

# %%
data.shape
# Out:
# (36, 8)

# %% [markdown]
# # to check the type of attributes

# %%
data.dtypes
# Out:
# State                      object
# Total Cases                 int64
# Active                      int64
# Discharged                  int64
# Deaths                      int64
# Total vaccination doses     int64
# Dose 1                      int64
# Dose 2                      int64
# dtype: object

# %% [markdown]
# # To check if there is any missing values

# %%
data.isnull()
# Out:
#     State  Total Cases  Active  Discharged  Deaths  Total vaccination doses  \
# 0   False        False   False       False   False                    False
# 1   False        False   False       False   False                    False
# 2   False        False   False       False   False                    False
# 3   False        False   False       False   False                    False
# 4   False        False   False       False   False                    False
# 5   False        False   False       False   False                    False
# 6   False        False   False       False   False                    False
# 7   False        False   False       False   False                    False
# 8   False        False   False       False   False                    False
# 9   False        False   False       False   False                    False
# 10  False        False   False       False   False                    False
# ...

# %% [markdown]
# # to check the number of diamension of the dataframe

# %%
data.ndim
# Out:
# 2

# %% [markdown]
# # print info of dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State                    36 non-null     object
#  1   Total Cases              36 non-null     int64
#  2   Active                   36 non-null     int64
#  3   Discharged               36 non-null     int64
#  4   Deaths                   36 non-null     int64
#  5   Total vaccination doses  36 non-null     int64
#  6   Dose 1                   36 non-null     int64
#  7   Dose 2                   36 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# # check the relationsship between data

# %%
data.corr
# Out:
# <bound method DataFrame.corr of                                        State  Total Cases  Active  Discharged  \
# 0                        Andaman And Nicobar         7541       4        7408
# 1                             Andhra Pradesh      1978350   20593     1944267
# 2                          Arunachal Pradesh        49668    3032       46399
# 3                                      Assam       572546   11719      555470
# 4                                      Bihar       725122     357      715119
# 5                                 Chandigarh        61970      27       61132
# 6                               Chhattisgarh      1002958    1780      987642
# 7   Dadra And Nagar Haveli And Daman And Diu        10652      12       10636
# 8                                      Delhi      1436623     516     1411042
# 9                                        Goa       171705     992      167556
# 10                                   Gujarat       825001     204      814720
# ...

# %% [markdown]
# # Heat map

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,3))
plt.bar(data['Deaths'],data['Total Cases'],color='Red')


plt.xlabel('Deaths')
plt.ylabel('Total Cases')
plt.title('Vaccination')
plt.show()

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(data["Total Cases"])
plt.show()

# %%
sns.boxplot(data["Deaths"])
plt.show()

# %% [markdown]
# # DisPlot

# %%
sns.distplot(data.Active)
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
sns.scatterplot(y=data["Active"],x=data["Deaths"])
plt.title("Active Vs Deaths hours",size=10)
plt.xlabel("Active Cases",size=12)
plt.ylabel("Deaths Cases",size=12)
plt.show()

# %% [markdown]
# # LINEAR REGRESSION

# %%
sns.regplot(y=data["Active"],x=data["Deaths"])
plt.title("Regressionplot",size=16)
plt.xlabel("Active Cases",size=15)
plt.ylabel("Deaths Cases",size=14)
plt.show()

# %%
data.corr()
# Out:
#                          Total Cases    Active  Discharged    Deaths  \
# Total Cases                 1.000000  0.678344    0.999882  0.910559
# Active                      0.678344  1.000000    0.667871  0.430221
# Discharged                  0.999882  0.667871    1.000000  0.912101
# Deaths                      0.910559  0.430221    0.912101  1.000000
# Total vaccination doses     0.709719  0.275594    0.715604  0.609315
# Dose 1                      0.676837  0.239117    0.683056  0.581222
# Dose 2                      0.788803  0.391355    0.793169  0.676718
#
#                          Total vaccination doses    Dose 1    Dose 2
# Total Cases                             0.709719  0.676837  0.788803
# Active                                  0.275594  0.239117  0.391355
# Discharged                              0.715604  0.683056  0.793169
# Deaths                                  0.609315  0.581222  0.676718
# Total vaccination doses                 1.000000  0.996723  0.956979
# ...

# %%
data.head()
# Out:
#                  State  Total Cases  Active  Discharged  Deaths  \
# 0  Andaman And Nicobar         7541       4        7408     129
# 1       Andhra Pradesh      1978350   20593     1944267   13490
# 2    Arunachal Pradesh        49668    3032       46399     237
# 3                Assam       572546   11719      555470    5357
# 4                Bihar       725122     357      715119    9646
#
#    Total vaccination doses    Dose 1   Dose 2
# 0                   308179    214334    93845
# 1                 23390769  17319963  6070806
# 2                   868372    685988   182384
# 3                 12089630   9977914  2111716
# 4                 26796305  22501851  4294454

# %% [markdown]
# # display the shape

# %%
X=data.iloc[:,2:]
Y=data.iloc[:,1]

# %%
X.head()
# Out:
#    Active  Discharged  Deaths  Total vaccination doses    Dose 1   Dose 2
# 0       4        7408     129                   308179    214334    93845
# 1   20593     1944267   13490                 23390769  17319963  6070806
# 2    3032       46399     237                   868372    685988   182384
# 3   11719      555470    5357                 12089630   9977914  2111716
# 4     357      715119    9646                 26796305  22501851  4294454

# %%
Y
# Out:
# 0        7541
# 1     1978350
# 2       49668
# 3      572546
# 4      725122
# 5       61970
# 6     1002958
# 7       10652
# 8     1436623
# 9      171705
# 10     825001
# 11     770042
# 12     207344
# 13     322286
# 14     347336
# 15    2915317
# 16    3513551
# 17      20378
# 18      10243
# 19     791937
# 20    6341759
# 21     102889
# 22      68107
# 23      43530
# 24      28445
# 25     984731
# 26     121421
# 27     599365
# 28     953793
# 29      27652
# 30    2571383
# 31     648388
# 32      79948
# 33    1708689
# 34     342336
# 35    1532379
# Name: Total Cases, dtype: int64

# %% [markdown]
# #  import the library to train ,test and split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (27, 6)
# (9, 6)
# (27,)
# (9,)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = regressor.predict(X_test)

# %%
Y_pred
# Out:
# array([  68107., 1978350.,  725122.,  791937., 1002958.,  770042.,
#         121421.,  984731.,  825001.,  648388.,   43530.])

# %%
accuracy = regressor.score(X_test,Y_pred)
"Accuracy: {}%".format(int(round(accuracy*100)))
# Out:
# 'Accuracy: 100%'

# %% [markdown]
# ### Comparing actual vs predicted

# %%
df = pd.DataFrame({"Actual": Y_test,"Predicted": Y_pred})
df
# Out:
#      Actual  Predicted
# 22    68107    68107.0
# 1   1978350  1978350.0
# 4    725122   725122.0
# 19   791937   791937.0
# 6   1002958  1002958.0
# 11   770042   770042.0
# 26   121421   121421.0
# 25   984731   984731.0
# 10   825001   825001.0
# 31   648388   648388.0
# 23    43530    43530.0

# %% [markdown]
# # Visualising the comparison

# %%
df.plot(kind="bar",figsize=(16,10))
plt.grid(which="major",linestyle="-",linewidth="0.5",color="green")
plt.grid(which="minor",linestyle=":",linewidth="0.5",color="black")
plt.show()
